# %%
import pandas as pd
data = pd.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
data.describe()
# Out:
#           ounces
# count   9.000000
# mean    6.055556
# std     2.855307
# min     3.000000
# 25%     4.000000
# 50%     6.000000
# 75%     7.500000
# max    12.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
# group     9 non-null object
# ounces    9 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 224.0+ bytes

# %%
data.sort_values(by=['group','ounces'], ascending=[False, True], inplace=True)
data
# Out:
#   group  ounces
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 1     a     3.0
# 0     a     4.0
# 2     a    12.0

# %%
import pandas as pd
data = pd.DataFrame({'k1': ['one'] * 3 + ['two'] * 4, 'k2': [3, 2, 1, 3, 3, 4, 4]})

# %%
import pandas as pd
data = pd.DataFrame({'k1': ['one'] * 3 + ['two'] * 4, 'k2': [3, 2, 1, 3, 3, 4, 4]})

# %%
data.sort_values(by='k2')
data
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
data.drop_duplicates()  # by default, duplicate is defined by all columns
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 5  two   4

# %%
data.drop_duplicates(subset='k1')  # duplicate in column k1 only
# Out:
#     k1  k2
# 0  one   3
# 3  two   3

# %%
import pandas as pd
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami','corned beef', 'Bacon', 'pastrami', 'honey ham','nova lox'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}

def meat2animal(series):
    if series["food"]=='bacon':
        return 'pig'
    elif series["food"]=='pulled pork':
        return 'pig'
    elif series["food"]=='pastrami':
        return 'cow'
    elif series["food"]=='corned beef':
        return 'cow'
    elif series["food"]=='honey ham':
        return 'pig'
    else:
        return 'salmon'

# %%
data['animal'] = data['food'].map(str.lower).map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
# axis=1 means to apply the function for each row, but I prefer to use axis='columns' instead
data['animal2'] = data.apply(meat2animal,axis='columns')
data
# Out:
#           food  ounces  animal animal2
# 0        bacon     4.0     pig     pig
# 1  pulled pork     3.0     pig     pig
# 2        bacon    12.0     pig     pig
# 3     Pastrami     6.0     cow  salmon
# 4  corned beef     7.5     cow     cow
# 5        Bacon     8.0     pig  salmon
# 6     pastrami     3.0     cow     cow
# 7    honey ham     5.0     pig     pig
# 8     nova lox     6.0  salmon  salmon

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})

df.assign(ratio = df['data1'] / df['data2'])
# Out:
#       data1     data2     ratio
# 0 -0.057598  0.288703 -0.199506
# 1 -1.486097 -0.955412  1.555451
# 2  0.079172  1.671613  0.047362
# 3  0.687178 -0.754419 -0.910872
# 4  0.848090 -0.322059 -2.633337

# %%
data.drop('animal2', axis='columns', inplace=True)  # dropping/removing a column
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
import pandas as pd
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.linspace(-3.14,3.14,10000)
plt.plot(a,np.sin(a))

# %%
plt.show()

# %%
data=[1,3,5,2,6,7,8,11,2,3,4,5,8,9]
data.sort()
b = data
b
# Out:
# [1, 2, 2, 3, 3, 4, 5, 5, 6, 7, 8, 8, 9, 11]

# %%
import pandas as pd
import numpy as np
#fp=open("C:ratings.dat")
#for i in fp:
#    x=fp.readline()
#    part=x.split("::")
#    if len(part)>1:
#        data=part[0:3]
#        print (data)
#        break
#        print(sorted(data))
        
df = pd.read_csv("c:ratings.dat")
x=df.as_matrix()
#x[0].split('::')
df.describe()
# Out:
#            1::1193::5::978300760
# count                    1000208
# unique                   1000208
# top     3120::2541::3::969900732
# freq                           1

# %%
import pandas as pd
data = pd.Series([1., -999., 2., -999., -1000., 3.])

# %%
data.replace([-999, -1000], np.nan, inplace=True)
data
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
import pandas as pd
data = pd.DataFrame(np.arange(12).reshape((3, 4)),index=['Ohio', 'Colorado', 'New York'],columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
data.index.map(str.upper)
# Out:
# array(['OHIO', 'COLORADO', 'NEW YORK'], dtype=object)

# %%
data.index = data.index.map(str.upper)
data
# Out:
#           one  two  three  four
# OHIO        0    1      2     3
# COLORADO    4    5      6     7
# NEW YORK    8    9     10    11

# %%
data.rename(index=str.title, columns=str.upper, inplace=True)  # str.title means to make the 1st letter capitalized only
data
# Out:
#           ONE  TWO  THREE  FOUR
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
import pandas as pd
data=pd.read_csv('c:ratings.dat',sep='::',header=None)
data.columns=['uder_id','movie_id','rating','timestamp']
data.sort_values(by=['rating'])
data
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#          uder_id  movie_id  rating  timestamp
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# 5              1      1197       3  978302268
# 6              1      1287       5  978302039
# 7              1      2804       5  978300719
# 8              1       594       4  978302268
# 9              1       919       4  978301368
# 10             1       595       5  978824268
# 11             1       938       4  978301752
# ...
